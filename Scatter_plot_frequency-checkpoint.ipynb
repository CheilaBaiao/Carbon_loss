# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
dir(stats)
import csv

#from matplotlib import rcParams
#rcParams['text.usetex'] = True
#rcParams['text.latex.preamble'] = r'\usepackage{amsmath}'

from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures

# %%
# Função de leitura dos dados------------------------------------
def pd_data(path):
    with open(path, newline='') as f:
        reader = csv.reader(f,delimiter=',')
        next(reader, None)  # ignora o cabeçalho
        for row in reader:
            try:
                data = np.vstack( (data , np.asarray(row).astype(np.float) ) )
            except:
                data = np.asarray(row).astype(np.float)
    f.close()
    return data

# %%
df = pd.read_excel ('freq_oficial.xlsx') #Read excel file
df.head()
# Out:
#      area  MÃªs  id1  lulc_1 IBGE  LULC  First year  2@@@  2@@@_  zero  ...  \
# 0   2.232     8    1   115.1    P   115        2001   0.0    0.0  2000  ...
# 1   2.729     8    2   115.1    P   115        2001   0.0    0.0  2000  ...
# 2  17.027     8    3   115.1    P   115        2001   0.0    0.0  2000  ...
# 3   2.315     8    4   115.1    P   115        2001   0.0    0.0  2000  ...
# 4   1.323     8    5   115.1    P   115        2001   0.0    0.0  2000  ...
#
#    2@19  2@19_  dezenove  2@2@  2@2@_  Vinte  Freq  FREQ  lulc_1.1  \
# 0   0.0    0.0      2019   0.0    0.0   2020     2     1     115.1
# 1   0.0    0.0      2019   0.0    0.0   2020     2     1     115.1
# 2   0.0    0.0      2019   0.0    0.0   2020     2     1     115.1
# 3   0.0    0.0      2019   0.0    0.0   2020     2     1     115.1
# 4   0.0    0.0      2019   0.0    0.0   2020     2     1     115.1
#
#    interval_mean
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# ...

# %%
df0 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@@@','2@@@_','zero','FREQ']]
df0 = df0.rename(columns={"2@@@": "area_year", "2@@@_": "Percentage", "zero": "Recurrent year"})

df1 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@@1','2@@1_','um','FREQ']]
df1 = df1.rename(columns={"2@@1": "area_year", "2@@1_": "Percentage", "um": "Recurrent year"})

df2 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@@2','2@@2_','dois','FREQ']]
df2 = df2.rename(columns={"2@@2": "area_year", "2@@2_": "Percentage", "dois": "Recurrent year"})

df3 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@@3','2@@3_','três','FREQ']]
df3 = df3.rename(columns={"2@@3": "area_year", "2@@3_": "Percentage", "três": "Recurrent year"})

df4 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@@4','2@@4_','quatro','FREQ']]
df4 = df4.rename(columns={"2@@4": "area_year", "2@@4_": "Percentage", "quatro": "Recurrent year"})

df5 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@@5','2@@5_','cinco','FREQ']]
df5= df5.rename(columns={"2@@5": "area_year", "2@@5_": "Percentage", "cinco": "Recurrent year"})

df6= df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@@6','2@@6_','seis','FREQ']]
df6 = df6.rename(columns={"2@@6": "area_year", "2@@6_": "Percentage", "seis": "Recurrent year"})

df7= df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@@7','2@@7_','sete','FREQ']]
df7 = df7.rename(columns={"2@@7": "area_year", "2@@7_": "Percentage", "sete": "Recurrent year"})

df8= df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@@8','2@@8_','oito','FREQ']]
df8 = df8.rename(columns={"2@@8": "area_year", "2@@8_": "Percentage", "oito": "Recurrent year"})

df9= df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@@9','2@@9_','nove','FREQ']]
df9 = df9.rename(columns={"2@@9": "area_year", "2@@9_": "Percentage", "nove": "Recurrent year"})

df10= df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@1@','2@1@_','dez','FREQ']]
df10= df10.rename(columns={"2@1@": "area_year", "2@1@_": "Percentage", "dez": "Recurrent year"})

df11= df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@11','2@11_','onze','FREQ']]
df11 = df11.rename(columns={"2@11": "area_year", "2@11_": "Percentage", "onze": "Recurrent year"})

df12 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@12','2@12_','doze','FREQ']]
df12 = df12.rename(columns={"2@12": "area_year", "2@12_": "Percentage", "doze": "Recurrent year"})

df13 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@13','2@13_','treze','FREQ']]
df13 = df13.rename(columns={"2@13": "area_year", "2@13_": "Percentage", "treze": "Recurrent year"})

df14 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@14','2@14_','catorze','FREQ']]
df14= df14.rename(columns={"2@14": "area_year", "2@14_": "Percentage", "catorze": "Recurrent year"})

df15 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@15','2@15_','quinze','FREQ']]
df15 = df15.rename(columns={"2@15": "area_year", "2@15_": "Percentage", "quinze": "Recurrent year"})

df16 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@16','2@16_','dezesseis','FREQ']]
df16 = df16.rename(columns={"2@16": "area_year", "2@16_": "Percentage", "dezesseis": "Recurrent year"})

df17 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@17','2@17_','dezessete','FREQ']]
df17 = df17.rename(columns={"2@17": "area_year", "2@17_": "Percentage", "dezessete": "Recurrent year"})

df18 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@18','2@18_','dezoito','FREQ']]
df18 = df18.rename(columns={"2@18": "area_year", "2@18_": "Percentage", "dezoito": "Recurrent year"})

df19 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@19','2@19_','dezenove','FREQ']]
df19= df19.rename(columns={"2@19": "area_year", "2@19_": "Percentage", "dezenove": "Recurrent year"})

df20 = df[['area','MÃªs','id1','lulc_1','IBGE','LULC','First year','2@2@','2@2@_','Vinte','FREQ']]
df20 = df20.rename(columns={"2@2@": "area_year", "2@2@_": "Percentage", "Vinte": "Recurrent year"})

total = pd.concat([df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20])
total
# Out:
#        area  MÃªs  id1  lulc_1 IBGE  LULC  First year  area_year  Percentage  \
# 0     2.232     8    1   115.1    P   115        2001        0.0         0.0
# 1     2.729     8    2   115.1    P   115        2001        0.0         0.0
# 2    17.027     8    3   115.1    P   115        2001        0.0         0.0
# 3     2.315     8    4   115.1    P   115        2001        0.0         0.0
# 4     1.323     8    5   115.1    P   115        2001        0.0         0.0
# ..      ...   ...  ...     ...  ...   ...         ...        ...         ...
# 537   1.239     7  538   115.1    P   115        2000        0.0         0.0
# 538   1.735     7  539   115.1    P   115        2000        0.0         0.0
# 539   1.322     9  540   203.4    r   203        2000        0.0         0.0
# 540   1.239     6  541   115.1    P   115        2000        0.0         0.0
# 541   2.148     7  542   115.1    P   115        2000        0.0         0.0
#
#      Recurrent year  FREQ
# ...

# %%
ax = sns.scatterplot(data=total, x="First year", y="FREQ", hue="IBGE")
ax.figure.set_size_inches(20,4)

# %% [markdown]
# Pearson average_pre x biomass nbr pre (0.9390486730707825, 4.7697734465263264e-70)
# Pearson average_pre x biomass NDVI pre (0.9325755700305685, 6.259291026447404e-67)
# Pearson average_post x biomass nbr post (0.9079079093024507, 2.2397154466212196e-57)
# Pearson average_post x biomass NDVI post (0.8793281245131204, 3.2342882819262132e-49)

# %%
spearmancorr= df.corr(method='spearman', min_periods=1)

# %%
def corr_sig(df):
    p_matrix = np.zeros(shape=(df.shape[1],df.shape[1]))
    for col in df.columns:
        for col2 in df.drop(col,axis=1).columns:
            _ , p = stats.spearmanr(df[col],df[col2])
            p_matrix[df.columns.to_list().index(col),df.columns.to_list().index(col2)] = p
    return p_matrix

p_values = corr_sig(df)
mask = np.invert(np.tril(p_values<0.05))
# note seaborn will hide correlation were the boolean value is True in the mask

# %%
def plot_cor_matrix(spearmancorr, mask=None):
    f, ax = plt.subplots(figsize=(20, 12))
    sns.set(font_scale=1.4)
    sns.heatmap(spearmancorr, ax=ax,
                mask=mask,
                # cosmetics
                annot=True, vmin=-1, vmax=1, center=0,annot_kws={"size": 16},fmt = '.1f',
                cmap='coolwarm', linewidths=1, linecolor='black', cbar_kws={'orientation': 'vertical'})

# %%
# Plotting with significance filter
corr = df.corr()                            # get correlation
p_values = corr_sig(df)                     # get p-Value
mask = np.invert(np.tril(p_values<0.05))    # mask - only get significant corr
#plot_cor_matrix(spearmancorr,mask)  
fig = plot_cor_matrix(spearmancorr,mask)
plt.savefig ('correlation_carbonloss.tif')
